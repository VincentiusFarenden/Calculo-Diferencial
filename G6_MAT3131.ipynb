# %% [markdown]
# # Problemas de Optimización

# %% [markdown]
# ## Objetivo:

# %% [markdown]
# En esta guía se trabajará con derivadas de funciones para optimizar procesos.
#
# A lo largo de esta guía deberá ser capaz de:
# - Determinar la función objetivo.
# - Encontrar las relaciones que generan restricciones.
# - Reescribir la función objetivo a partir de las restricciones.
# - Encontrar valores óptimos sujetos a restricciones.
# - Comprender la idea del método de optimización por descenso del gradiente.
# - Aplicar el método de descenso del gradiente a modelos con un único parámetro.

# %% [markdown]
# ## Instrucciones

# %% [markdown]
# Esta guía contiene problemas de optimización de funciones, que debe resolver tanto de forma analítica como de forma computacional.
#
# - Los problemas marcados con 📝 se deben resolver con lápiz y papel en su cuaderno.
#
# - Los problemas marcados con 💻/🐍 debe resolverlos usando Python.

# %%
# @title
# %%html
<div style="border: 4px solid #006d77; border-radius: 0px; overflow: hidden; font-family: sans-serif; max-width: 1000px; margin-bottom: 20px;">

  <div style="background-color: #000000; color: #ffc107; padding: 10px 15px; font-weight: bold; font-size: 18px; display: flex; align-items: center;">
    <span style="margin-right: 10px; font-size: 18px;">💡</span>
    <span>¿Qué es un problema de optimización? </span>
  </div>

  <div style="background-color: #ffffff; padding: 30px; display: flex; align-items: center; justify-content: space-between;">

    <div style="color: #000000; flex: 1; padding-right: 30px; font-size: 16px; line-height: 1.5;">
      ¿Cómo abordar un problema de optimización?
      <b>Escanea o haz clic sobre el código QR</b> para revisar cómo identificar la función objetivo, reconocer restricciones y
       usar derivadas para encontrar un valor óptimo en contextos aplicados, como rendimiento, costos o distribución de recursos computacionales.
    </div>

    <div style="flex-shrink: 0;">
      <a href="https://duoc.h5p.com/content/1292752615678918338" target="_blank">
        <img src="https://i.ibb.co/yFY6L19c/opti.png"
             alt="QR Code"
             style="width: 130px; height: 130px; border: none;">
      </a>
    </div>

  </div>

  <div style="background-color: #000000; color: #ffc107; padding: 8px 15px; font-weight: bold; font-size: 18px;">
    Presentación interactiva H5P
  </div>

</div>
# Out:
# <div style="border: 4px solid #006d77; border-radius: 0px; overflow: hidden; font-family: sans-serif; max-width: 1000px; margin-bottom: 20px;">
#
#   <div style="background-color: #000000; color: #ffc107; padding: 10px 15px; font-weight: bold; font-size: 18px; display: flex; align-items: center;">
#     <span style="margin-right: 10px; font-size: 18px;">💡</span>
#     <span>¿Qué es un problema de optimización? </span>
#   </div>
#
#   <div style="background-color: #ffffff; padding: 30px; display: flex; align-items: center; justify-content: space-between;">
#
#     <div style="color: #000000; flex: 1; padding-right: 30px; font-size: 16px; line-height: 1.5;">
#       ¿Cómo abordar un problema de optimización?
#       <b>Escanea o haz clic sobre el código QR</b> para revisar cómo identificar la función objetivo, reconocer restricciones y
#        usar derivadas para encontrar un valor óptimo en contextos aplicados, como rendimiento, costos o distribución de recursos computacionales.
# ...

# %% [markdown]
# ## Problemas

# %% [markdown]
# ### Problema 1 📝

# %% [markdown]
# Un granjero tiene 2.400 metros de cerca y desea rodear un campo rectangular que limita con un río recto. Para ello, debe cercar los tres lados del campo (excluyendo el lado del río), tal como se muestra en la figura:

# %% [markdown]
# <div align="center">
# <img src="data:image/png;base64,..." width="400">
# </div>
#
# Basándose en lo anterior, responda:

# %% [markdown]
# a) ¿Qué representan $x$ e $y$ en el contexto del problema? Indique sus unidades de medida.

# %% [markdown]
# b) ¿Cuál es la expresión para el área del campo en términos de $x$ e $y$?

# %% [markdown]
# c) ¿Cuál es la expresión para la longitud de la cerca en términos de $x$ e $y$?

# %% [markdown]
# d) Escriba la función que representa el área y la ecuación que representa la restricción en términos de $x$ e $y$.

# %% [markdown]
# e) Despejando $x$ en la restricción, construya la función objetivo.

# %% [markdown]
# f) Determine el valor de $y$ que hace que el área sea máxima.

# %% [markdown]
# g) Utilizando la restricción, determine cuánto mide el ancho del terreno.

# %% [markdown]
# h) ¿Cuál es el área máxima que se puede cercar?

# %% [markdown]
# ### Problema 2 📝

# %% [markdown]
# Un granjero dispone de 750 metros de cerca y desea rodear un campo rectangular y dividirlo en cuatro corrales iguales, con un cercado interior paralelo al lado $y$ del rectángulo, como muestra la imagen.

# %% [markdown]
# <div align="center">
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# a) ¿Qué representan $x$ e $y$ en el contexto del problema?

# %% [markdown]
# b) ¿Cuál es la expresión para el área del campo en términos de $x$ e $y$?

# %% [markdown]
# c) ¿Cuál es la expresión para la longitud total de la cerca en términos de $x$ e $y$?

# %% [markdown]
# d) Escriba la función que representa el área y la ecuación que representa la restricción en términos de $x$ e $y$.

# %% [markdown]
# e) Despejando $y$ en la restricción, construya la función objetivo.

# %% [markdown]
# f) Determine el valor de $x$ que hace que el área sea máxima.

# %% [markdown]
# g) Utilizando la restricción, determine los valores que maximizan el área de cada corral.

# %% [markdown]
# h) ¿Cuál es el área máxima que se puede cercar?

# %% [markdown]
# ### Problema 3 💻/🐍

# %% [markdown]
# Una constructora debe cercar un terreno rectangular de 5.000 metros cuadrados para una nueva obra.
# Los costos de instalación dependen de la ubicación de los lados:
#
# •	El frente del terreno (lado que da a la calle) requiere un cierre opaco de seguridad que cuesta \$15.000 por metro.
#
# •	Los otros tres lados (el fondo y los dos laterales) se cerrarán con malla simple a un costo de \$5.000 por metro.

# %% [markdown]
# <div align="center">
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# El objetivo del proyecto es minimizar el costo total del cercado. Responda lo siguiente:
#
# a) Defina claramente qué representan las variables $x$ e $y$ en este contexto.

# %% [markdown]
# b) Construya la función de Costo total y la ecuación de la restricción (área).

# %% [markdown]
# c) Obtenga la Función objetivo que dependa únicamente de la variable del frente ($x$).

# %% [markdown]
# d)	Utilizando las herramientas de cálculo simbólico (Sympy), encuentre los valores críticos de la función objetivo.

# %% [markdown]
# e)	Aplique el criterio de la segunda derivada para determinar si el valor crítico genera un máximo o un mínimo.

# %% [markdown]
# f)	Determine las dimensiones finales del terreno y el valor del costo óptimo del cercado.

# %% [markdown]
# ### Problema 4 💻/🐍

# %% [markdown]
# Una aplicación web divide un archivo grande en dos partes para enviarlo a través de internet utilizando dos servidores distintos: A y B. La variable $x$ representa la cantidad de datos (en MB) asignada al servidor A, mientras que $y$ representa la cantidad de datos (en MB) asignada al servidor B.
#
# El tiempo total estimado de transferencia, medido en milisegundos (ms), está dado por la siguiente función:
#
# $$T(x,y)=\frac{60}{x}+\frac{40}{y}$$
#
# Se sabe que el tamaño total del archivo que se debe transferir es de 60 MB.

# %% [markdown]
# a) ¿Cuál es la restricción del problema?

# %% [markdown]
# b) Defina las variables simbólicas y la ecuación de restricción en una celda de código.

# %% [markdown]
# c) Utilizando Python, despeje la restricción del problema y exprésela en términos de la variable $x$.

# %% [markdown]
# d) Construya la función objetivo $T(x)$.

# %% [markdown]
# e) 	Utilice SymPy para obtener la primera derivada de la función $(T'(x))$, busque los valores críticos y encuentre la distribución óptima de MB para cada servidor.

# %% [markdown]
# f) 	Suponga que el administrador decide asignar la cantidad de datos de forma equitativa ($x = 30$, $y=30$) "para ser justos", en lugar de usar el óptimo calculado. Use Python para evaluar en ambos casos y calcule qué porcentaje de tiempo extra se pierde por tomar la decisión "equitativa" en lugar de la "óptima".

# %% [markdown]
# ### Problema 5 📝

# %% [markdown]
# Se requiere fabricar una lata de aceite cilíndrica, que contenga 1 litro de aceite (1.000 cm$^3$).
#
# El objetivo de este problema es determinar las dimensiones del radio $r$ y la altura $h$ (en cm) que minimizan la cantidad de material necesario para fabricar la lata.
#
# Nota:
#
# - El área de la superficie del cilindro está dada por:
#
# $$A(r,h)=2\pi r^2+2\pi rh$$
#
# - El volumen de un cilindro está dado por:
#
# $$V(r,h)=\pi r^2h$$
#
# Considere $\pi=3,14$

# %% [markdown]
# <div align="center">
# <img src="data:image/png;base64,..." width="170">

# %% [markdown]
# a) ¿Cuál es la restricción que se impone sobre el problema? ¿Cómo se representa mediante una ecuación?

# %% [markdown]
# b) Considerando las restricciones, despeje $h$ en términos de $r$ y construya la función objetivo $A(r)$.

# %% [markdown]
# c) Determine $A'(r)$. ¿Qué ecuación debe satisfacer $r$ para que sea un valor crítico de la función?

# %% [markdown]
# d) Se implementa el siguiente código, donde $A(r)$ corresponde a la función obtenida en b). ¿Cómo se interpreta la salida de este código?

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# e) Verifique si el extremo encontrado genera un mínimo o un máximo.

# %% [markdown]
# f) ¿Cuáles son las dimensiones de $r$ y $h$ que minimizan el material utilizado para construir la lata?

# %% [markdown]
# g) ¿Cuál es la mínima cantidad de material necesaria para construir la lata?

# %% [markdown]
# ### Problema 6 📝

# %% [markdown]
# Se cuenta con 1.200 cm$^2$ de material para construir una caja de base cuadrada y la parte superior abierta, como muestra la figura.

# %% [markdown]
# <div align="center">
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# El objetivo de este problema es determinar las dimensiones ( $x$ y $h$ ) que maximizan el volumen de la caja. Para esto responda las siguientes preguntas:

# %% [markdown]
# a) 	Defina qué representan $x$ y $h$. Luego, escriba las expresiones algebraicas para el área total y para el volumen de la caja.
# Nota: Para esto considere calcular la suma del área de la base y de cada una de las paredes.

# %% [markdown]
# b) 	Encuentre la función objetivo del problema en términos de $x$.

# %% [markdown]
# c) Determine $V'(x)$.

# %% [markdown]
# d) Se implementó el siguiente código en Python, donde $V(x)$ corresponde a la función encontrada en el inciso b). ¿Qué representan las salidas del código? ¿Ambas tienen sentido en el contexto del problema?

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# e) ¿Cuáles son las dimensiones de la caja ($x$ y $h$) que maximizan el volumen? ¿Cuál es el volumen máximo?

# %% [markdown]
# ### Problema 7 📝

# %% [markdown]
# Una empresa de servicios en la nube desarrolla una API que atiende miles de solicitudes por segundo. Para mejorar el rendimiento, el sistema asigna la memoria RAM disponible a dos componentes críticos:
# - $x$ MB para guardar resultados recientes (caché).
# - $y$ MB para la cola de procesamiento.
#
#
# El tiempo promedio de respuesta por solicitud (en milisegundos) se modela como:
#
# $$T(x,y)=\frac{2.000}{x}+\frac{1.000}{y}$$
#
# El servidor sólo dispone de 800 MB de memoria para ambos componentes.
#
# a) Construya la función objetivo $T(y)$ en términos de la memoria asignada a la cola.

# %% [markdown]
# b) 	Para encontrar la solución óptima, se calcula la derivada $T'(y)$ y se aplica el siguiente código:

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# ¿Qué representan los valores de salida? ¿Ambos tienen sentido en el contexto del problema?

# %% [markdown]
# c) Si sabemos que $T''(331,37)>0$. ¿Cuánta RAM debe asignarse a cada componente para minimizar el tiempo promedio de solicitud? ¿Cuál es el tiempo promedio de solicitud mínimo?

# %% [markdown]
# ### Problema 8 💻/🐍

# %% [markdown]
# Un sistema de recomendación (tipo Netflix) distribuye recursos computacionales entre dos sub-procesos para mejorar la calidad de sus sugerencias:
#
# - $x$: Unidades de procesamiento para determinar la relevancia del contenido.
# - $y$: Unidades de procesamiento para analizar la similitud con otros usuarios.
#
# La Fiabilidad del Sistema, $S(x,y)$, se expresa como un porcentaje en una escala del 0% al 100% y se calcula mediante la función:
#
# $$S(x,y)=10\sigma(2x-y)xy$$
#
# Donde $\sigma$ es la función sigmoide dada por:
#
# $$\sigma(z)=\frac{1}{1+e^{-z}}$$
#
#
# Cuando $S(x,y)→100\%$, el sistema recomendará contenidos adecuados, mientras que cuando $S(x,y)→0\%$, el sistema no hará recomendaciones adecuadas.
#
# Los recursos de hardware son limitados, imponiendo la siguiente restricción de consumo:
#
# $$3x+y=12$$
#
# El objetivo de este problema es encontrar cuál es la mayor fiabilidad a la que podemos llegar. Para esto, responda las siguientes preguntas:
#
# a) ¿Cuál es la función objetivo $S(x)$?
#
# Nota: Para obtenerla en Python considere:
#
#   i) Definir las variables simbólicas.
#
#   ii) Definir las funciones $σ(z)$ y $S(x,y)$.
#
#   iii) Utilizar la restricción para encontrar una expresión de $y$ en términos de $x$, y sustituir este resultado en la fórmula de $S(x,y)$.

# %% [markdown]
# b) Determine la derivada de la función objetivo, es decir, $S'(x)$.

# %% [markdown]
# c) Se sabe que $x=2,836$ es un valor crítico. Determine la naturaleza de este valor crítico, es decir, ¿genera un máximo o un mínimo?

# %% [markdown]
# d) ¿Cuántas unidades de procesamiento se deben asignar a cada proceso ($x$ e $y$) para optimizar la fiabilidad del modelo? ¿Cuál es el valor máximo de la fiabilidad del modelo?

# %% [markdown]
# ### Problema 9 💻/🐍

# %% [markdown]
# El consumo energético de un dispositivo móvil distribuye su potencia total entre dos componentes críticos: la CPU y la GPU.
#
# Sean:
# - $x$: Potencia asignada a la CPU en mW (miliWatts).
#
# - $y$: Potencia asignada a la GPU en mW.
#
# El rendimiento global del sistema se modela mediante la siguiente función de desempeño, donde el resultado se expresa en puntos:
#
# $$P(x,y)=\sqrt{x}+2\sqrt{y}$$
#
# El objetivo es maximizar este desempeño, pero considerando que el presupuesto total energético de la batería está limitado: no puede exceder los 1.000 mW (asumiremos que se utiliza toda la energía disponible). Para esto, responde:
#
# a) ¿Cuál es la función que se desea optimizar y cuál es la ecuación que representa la restricción?

# %% [markdown]
# b) Utilizando Python, construya la función objetivo.

# %% [markdown]
# c) Determine los valores de $x$ e $y$ que optimizan el desempeño.

# %% [markdown]
# d) ¿Cuál es el puntaje máximo de desempeño?

# %% [markdown]
# ### Problema 10 📝

# %% [markdown]
# Hasta el momento, la optimización se ha realizado encontrando los puntos donde la derivada es cero. Sin embargo, en aplicaciones de Ciencia de Datos e Inteligencia Artificial, a menudo las funciones objetivo son demasiado complejas para ser despejadas algebraicamente.
#
# Para estos casos se utiliza el algoritmo del **Descenso del Gradiente**, un método iterativo que busca el mínimo numérico ajustando los parámetros paso a paso en la dirección opuesta a la pendiente (gradiente).
#
# Suponga que la función objetivo (que representa el error de un modelo) está dada por la parábola:
#
# $$E(w)=2w^2-12w+40$$
#
# El objetivo es aproximar el valor del parámetro $w$ que minimiza este error mediante iteraciones manuales. Para esto, realice los siguientes pasos:
#
# a) Obtenga la función derivada $E'(w)$. Evalúela en el punto inicial $w_0  = 0$. Basándose en el signo del resultado, determine si la función crece o decrece en ese valor.

# %% [markdown]
# b) El algoritmo actualiza la posición del parámetro mediante la siguiente regla de iteración:
#
# $$w_{n+1}=w_n-\alpha E'(w_n)$$
#
# Considerando una tasa de aprendizaje $\alpha=0,1$ y partiendo de $w_0=0$, realice 3 iteraciones manuales completando la siguiente tabla:
#
# | Interación ($n$) | Posición actual ($w_n$) |Gradiente $E'(w_n)$|Paso ($-\alpha E'$) | Nueva posición ($w_{n+1}$) |
# |:--:|:--:|:--:|:--:|:--:|
# | *0* | 0 |-12| +1,2 | 1,2 |
# | *1* | 1,2 |...| ... | ... |
# | *2* | ... |...| ... | ... |
# | *3* | ... |...| ... | ... |

# %% [markdown]
# c) Determine analíticamente el valor exacto de $w$ que minimiza la función (resolviendo $E'(w)=0$). Compare este valor real con el resultado obtenido en la tercera iteración ($w_4$). ¿Se observa que el algoritmo converge hacia el mínimo?

# %% [markdown]
# ### Problema 11 💻/🐍

# %% [markdown]
# Un servidor web procesa solicitudes y se sospecha que el tiempo total de procesamiento es aproximadamente proporcional a la cantidad de registros revisados:
#
# $$T(n)\approx k\cdot n$$
#
# donde $n$ es la cantidad de registros, $T$ es el tiempo total (en milisegundos) y $k$ es el tiempo promedio por registro (milisegundos por registro) que se desea estimar.
#
# Los datos están disponibles **[aquí](https://docs.google.com/spreadsheets/d/1rnJSwpUST7C5bu-GYk5PFJJo0bsXmMx6/export?format=xlsx)**. El archivo contiene dos columnas llamadas: Cantidad de registros y Tiempo medido.
#
# a)	Importe la base de datos usando Python (puede usar Pandas) y asigne:
#
# - $n$ = columna de Cantidad de registros.
# - $T$ = columna de Tiempo medido.

# %% [markdown]
# b) Considere como predicción del modelo:
#
# $$T_{pred}=k\cdot n$$
#
# En Python, calcule las predicciones de $T$, use $k_0= 0,01$.

# %% [markdown]
# c) 	Se define el *error promedio cuadrático* como el promedio de las diferencias al cuadrado entre la predicción y el valor real, matemáticamente esto es:
#
# $$E(k)=\text{promedio}((kn-T)^2)$$
#
# Para aplicar descenso del gradiente utilizaremos la derivada (gradiente) de $E(k)$:
#
# $$E' (k)=2⋅\text{promedio} ((k n-T) n)$$
#
# En Python, defina las funciones que calculen $E(k)$ y $E'(k)$.
#
# Nota: En Pandas, si $n$ y $T$ son columnas, expresiones como $k*n - T$ se calculan automáticamente para todos los datos.

# %% [markdown]
# d) Aplique la regla de iteración:
# $$k_{(t+1)}=k_t-α E'(k_t)$$
#
# Use $k_0=0,01$ y $α=0,000001$. Realice 10 iteraciones y registre en una tabla (puede ser un DataFrame o impresiones ordenadas) las columnas: iteración, valor de $k$ y $E(k)$. Según la tabla obtenida, ¿el error $E(k)$ tiende a estabilizarse al avanzar las iteraciones? Justifique con el comportamiento de $E(k)$.

# %% [markdown]
# e) Con el valor final de $k$, escriba el modelo final $T(n)=k⋅n$ y estime el tiempo para una solicitud con $n=4.500$ registros.

# %% [markdown]
# ### Problema 12 💻/🐍

# %% [markdown]
# En un sistema se mide la tasa de fallos de caché (en %) en función del tamaño de caché s (en MB). Se sospecha que la tasa de fallos se puede modelar aproximadamente como una exponencial decreciente:
#
# $$F(s)\approx100e^{-ks}$$
#
# donde $F(s)$ es el porcentaje de fallos de caché y $k>0$ es un parámetro que indica qué tan rápido disminuyen los fallos al aumentar el tamaño de caché.
# Los datos están disponibles **[aquí.](https://docs.google.com/spreadsheets/d/1GamUhdr-DOqkZxNNaQX9dzhXatWwVxgG/export?format=xlsx)**

# %% [markdown]
# a)	Importe la base de datos usando Python (puede usar Pandas) y asigne:
# - $s$ = columna de Tamaño del caché (MB).
# - $F$ = columna de Fallos del caché medidos en %.

# %% [markdown]
# b) Considere como predicción del modelo:
# $$F_{pred}=100e^{-ks}$$
# En Python, calcule las predicciones de $F$, use $k_0= 1$.

# %% [markdown]
# c) Se define el *error promedio cuadrático* como:
# $$E(k)=\text{promedio}((100e^{-ks}-F)^2)$$
#
# Para aplicar descenso del gradiente utilizaremos la derivada de $E(k)$:
#
# $$E'(k)=2\cdot \text{promedio}((100e^{-ks}-F)\cdot(-100se^{-ks} ) )$$
#
# En Python, defina las funciones que calculen $E(k)$ y $E'(k)$.

# %% [markdown]
# d) Aplique la regla de iteración:
# $$k_{(t+1)}=k_t-\alpha E'(k_t)$$
#
# Use $k_0=1$ y $\alpha=0,0001$. Realice 30 iteraciones y registre en una tabla (puede ser un DataFrame o impresiones ordenadas) las columnas: iteración, valor de $k$ y $E(k)$.
# Según la tabla obtenida, ¿el error $E(k)$ tiende a estabilizarse al avanzar las iteraciones? Justifique con el comportamiento de $E(k)$.

# %% [markdown]
# e) 	Con el valor final de $k$, escriba el modelo final $F(s)=100e^{-ks}$ y estime la tasa de fallos para que $s=32$ MB.
