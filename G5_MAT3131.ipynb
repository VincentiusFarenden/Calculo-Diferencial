# %% [markdown]
# <img src="https://i.ibb.co/93sNcdhp/Logo-pmat-color.png" align="right" width="150">
#
# <br>
#
# # Máximos y Mínimos

# %% [markdown]
# ## Objetivo:

# %% [markdown]
# En esta guía se trabajará con derivadas de funciones para obtener máximos y mínimos.
#
# A lo largo de esta guía deberá ser capaz de:
# - Encontrar valores críticos de funciones.
# - Determinar la naturaleza de los valores críticos.
# - Encontrar máximos y mínimos locales de las funciones.
# - Encontrar máximos y mínimos globales de las funciones.

# %% [markdown]
# ## Instrucciones

# %% [markdown]
# Esta guía contiene problemas relacionados con máximos y mínimos de funciones, que debe resolver tanto de forma analítica como de forma computacional.
#
# - Los problemas marcados con 📝 son los que debe resolver con lápiz y papel en su cuaderno.
#
# - Los problemas marcados con 💻/🐍 debe resolverlos usando Python.

# %%
# @title
# %%html
<div style="border: 4px solid #006d77; border-radius: 0px; overflow: hidden; font-family: sans-serif; max-width: 1000px; margin-bottom: 20px;">

  <div style="background-color: #000000; color: #ffc107; padding: 10px 15px; font-weight: bold; font-size: 18px; display: flex; align-items: center;">
    <span style="margin-right: 10px; font-size: 18px;">💡</span>
    <span>Puntos críticos, máximos, mínimos e inflexión</span>
  </div>

  <div style="background-color: #ffffff; padding: 30px; display: flex; align-items: center; justify-content: space-between;">

    <div style="color: #000000; flex: 1; padding-right: 30px; font-size: 16px; line-height: 1.5;">
      ¿Cómo reconocer los puntos importantes de una función?
      <b>Escanea o haz clic sobre el código QR</b> para revisar visualmente qué son los puntos críticos, máximos, mínimos y puntos de inflexión.
      Observa cómo el comportamiento de la gráfica permite distinguir entre extremos locales, extremos globales y cambios de curvatura.
    </div>

    <div style="flex-shrink: 0;">
      <a href="https://duoc.h5p.com/content/1292775298185767188" target="_blank">
        <img src="https://i.ibb.co/k6mshNnt/maxymin.png"
             alt="QR Code"
             style="width: 130px; height: 130px; border: none;">
      </a>
    </div>

  </div>

  <div style="background-color: #000000; color: #ffc107; padding: 8px 15px; font-weight: bold; font-size: 18px;">
    Presentación interactiva H5P
  </div>

</div>
# Out:
# <div style="border: 4px solid #006d77; border-radius: 0px; overflow: hidden; font-family: sans-serif; max-width: 1000px; margin-bottom: 20px;">
#
#   <div style="background-color: #000000; color: #ffc107; padding: 10px 15px; font-weight: bold; font-size: 18px; display: flex; align-items: center;">
#     <span style="margin-right: 10px; font-size: 18px;">💡</span>
#     <span>Puntos críticos, máximos, mínimos e inflexión</span>
#   </div>
#
#   <div style="background-color: #ffffff; padding: 30px; display: flex; align-items: center; justify-content: space-between;">
#
#     <div style="color: #000000; flex: 1; padding-right: 30px; font-size: 16px; line-height: 1.5;">
#       ¿Cómo reconocer los puntos importantes de una función?
#       <b>Escanea o haz clic sobre el código QR</b> para revisar visualmente qué son los puntos críticos, máximos, mínimos y puntos de inflexión.
# ...

# %%
# @title
# %%html
<div style="border: 4px solid #006d77; border-radius: 0px; overflow: hidden; font-family: sans-serif; max-width: 1000px; margin-bottom: 20px;">

  <div style="background-color: #000000; color: #ffc107; padding: 10px 15px; font-weight: bold; font-size: 18px; display: flex; align-items: center;">
    <span style="margin-right: 10px; font-size: 18px;">💡</span>
    <span>Criterios para clasificar máximos, mínimos e inflexiones</span>
  </div>

  <div style="background-color: #ffffff; padding: 30px; display: flex; align-items: center; justify-content: space-between;">

    <div style="color: #000000; flex: 1; padding-right: 30px; font-size: 16px; line-height: 1.5;">
      ¿Cómo clasificar máximos, mínimos o inflexiones usando derivadas?
      <b>Escanea o haz clic sobre el código QR</b> para revisar dos criterios de clasificación: el cambio de signo de la primera derivada
      y el criterio de la segunda derivada. Observa cómo cada método permite decidir si un punto corresponde a un máximo local,
      un mínimo local o si se requiere revisar el comportamiento de la función con más detalle.
    </div>

    <div style="flex-shrink: 0;">
      <a href="https://duoc.h5p.com/content/1292775299464440628" target="_blank">
        <img src="https://i.ibb.co/1ty6cHBD/criterios.png"
             alt="QR Code"
             style="width: 130px; height: 130px; border: none;">
      </a>
    </div>

  </div>

  <div style="background-color: #000000; color: #ffc107; padding: 8px 15px; font-weight: bold; font-size: 18px;">
    Presentación interactiva H5P
  </div>

</div>
# Out:
# <div style="border: 4px solid #006d77; border-radius: 0px; overflow: hidden; font-family: sans-serif; max-width: 1000px; margin-bottom: 20px;">
#
#   <div style="background-color: #000000; color: #ffc107; padding: 10px 15px; font-weight: bold; font-size: 18px; display: flex; align-items: center;">
#     <span style="margin-right: 10px; font-size: 18px;">💡</span>
#     <span>Criterios para clasificar máximos, mínimos e inflexiones</span>
#   </div>
#
#   <div style="background-color: #ffffff; padding: 30px; display: flex; align-items: center; justify-content: space-between;">
#
#     <div style="color: #000000; flex: 1; padding-right: 30px; font-size: 16px; line-height: 1.5;">
#       ¿Cómo clasificar máximos, mínimos o inflexiones usando derivadas?
#       <b>Escanea o haz clic sobre el código QR</b> para revisar dos criterios de clasificación: el cambio de signo de la primera derivada
# ...

# %% [markdown]
# ## Problemas

# %% [markdown]
# ### Problema 1 📝

# %% [markdown]
# La eficiencia de un servidor web, medida en cientos de solicitudes procesadas por minuto, se modela mediante la función:
#
# $$R(x)=-2x^2+12x+5$$
#
# donde $x$ representa la carga del servidor en miles de usuarios conectados, con $x$ en el intervalo $[0,6]$
#
# a) Determine la derivada $R'(x)$.

# %% [markdown]
# b) Determine el/los valores de $x$ para los cuales la derivada es cero (valores críticos).

# %% [markdown]
# c) Construye una tabla evaluando la derivada en valores de $x$ dentro del dominio contextualizado, antes y después del valor encontrado en el inciso anterior.

# %% [markdown]
# d) A partir del análisis anterior, indique los intervalos en los que la función crece y decrece dentro del dominio dado.

# %% [markdown]
# e) ¿La función presenta un máximo o un mínimo en el dominio? Justifique su respuesta y señale para qué nivel de carga ocurre dicha situación.

# %% [markdown]
# f) Considerando los valores críticos calculados, y el comportamiento del crecimiento de la función, bosqueje la gráfica.

# %% [markdown]
# ### Problema 2 📝

# %% [markdown]
# Un vehículo se desplaza por una carretera recta. La posición $d$, medida en metros desde el punto de partida, está dada por la expresión:
#
# $$d(t)=t^2-6t+5$$
#
# donde $t$ corresponde al tiempo, medido en segundos, desde que el vehículo comenzó su movimiento.
#
# a) Determine la derivada $d'(t)$.

# %% [markdown]
# b) Determine el/los valores de $t$ para los cuales la derivada es cero (valores críticos).

# %% [markdown]
# c) Construye una tabla evaluando la derivada en valores de $t$ dentro del dominio contextualizado, antes y después del valor encontrado en el inciso anterior.

# %% [markdown]
# d) A partir del análisis anterior, indique los intervalos en los que la función crece y decrece.

# %% [markdown]
# e) ¿La función presenta un máximo o un mínimo en el dominio? Justifique su respuesta.

# %% [markdown]
# f) Considerando los valores críticos calculados, y el comportamiento del crecimiento de la función, bosqueje la gráfica.

# %% [markdown]
# ### Problema 3 💻/🐍

# %% [markdown]
# Una empresa logística, determina el costo total de almacenaje y distribución de un pedido, en miles de pesos, mediante la función:
#
# $$C(x)=2x+\frac{299.538}{x}$$
#
# Donde $x$ representa la cantidad de artículos del pedido, considerando como mínimo 50 artículos.
#
# a) Determine cuáles son las variables dependiente e independiente, indicando su unidad de medida.

# %% [markdown]
# - Variable independiente (x): Cantidad de articulos del pedido en unidades
# - Variable dependiente (y): El costo total de almacenaje en miles de pesos

# %% [markdown]
# b) Determine el dominio contextualizado del problema.

# %% [markdown]
# Dom C=[50, oo]

# %% [markdown]
# c) Calcule la derivada de la función costo y determine los valores críticos, es decir, los valores de $x$ para los cuales $C’(x) = 0$.

# %% [markdown]
# d) A partir de los valores críticos obtenidos y del dominio contextualizado del problema, analice para qué cantidad de artículos el costo total es el menor posible. Justifique su respuesta.

# %% [markdown]
# ### Problema 4 💻/🐍

# %% [markdown]
# La virulencia$^1$ de una cierta bacteria, se comenzó a estudiar a comienzos del año 2000, obteniendo el siguiente modelo:
#
# $$V(x)=\frac{1}{40}x^4-\frac{8}{30}x^3+0,35x^2+15$$
#
# Donde $V$ corresponde a la virulencia en porcentaje y $x$ a los años transcurridos desde inicios del año 2000.
#
# $^1$Es el grado de la capacidad de producir una enfermedad.

# %% [markdown]
# a) Si el modelo es válido hasta inicios del 2010, ¿cuál es el dominio contextualizado del problema?

# %% [markdown]
# b) Determine los valores críticos de la función que modela el problema.

# %% [markdown]
# c) Determine los periodos en que la virulencia aumenta y disminuye.

# %% [markdown]
# d) Grafique la función considerando el dominio contextualizado.

# %% [markdown]
# e) Observando el gráfico, ¿en qué año la virulencia alcanza su mayor valor? Calcule cuál es ese valor.

# %% [markdown]
# ### Problema 5 📝

# %% [markdown]
# Durante una sesión de preparación final para una competencia, un ciclista de alto rendimiento entrena durante 7 horas continuas. La rapidez del ciclista, en kilómetros por hora, está modelada por la función:
#
# $$V(t)=t^3-12t^2+36t$$
#
# donde $t$ representa el tiempo transcurrido en horas.
#
# a) Determine el dominio contextualizado del problema.

# %% [markdown]
# b) Determine la derivada de la rapidez $V(t)$, es decir, $V'(t)$.

# %% [markdown]
# c) Se implementa el siguiente código. ¿Cómo se interpretan las salidas?

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# d) Considerando el signo de $V'(t)$ y lo obtenido en el inciso c), determine los intervalos de crecimiento y decrecimiento.

# %% [markdown]
# e) ¿Cuál es la rapidez máxima y mínima del ciclista?

# %% [markdown]
# ### Problema 6 📝

# %% [markdown]
# Al comienzo de una carretera de 21 kilómetros de largo, se ubica una planta industrial que emite gases contaminantes.
#
# Por normativa, no se pueden construir casas a menos de 6 kilómetros de esa planta.
#
# Si $x$ representa la distancia a la planta, a lo largo de la carretera, la cantidad de partículas contaminantes en el aire, en partículas por millón (ppm), se puede determinar por la función:
#
# $$C(x)=2x^3-69x^2+720x-1.500$$

# %% [markdown]
# a) Determine la función $C'(x)$.

# %% [markdown]
# b) Si se implementa el siguiente código:

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# ¿Cómo se interpreta su salida?

# %% [markdown]
# c) Determine los intervalos de crecimiento y decrecimiento de $C(x)$.

# %% [markdown]
# d) Determine los máximos y mínimos de $C(x)$ y determine su valor.

# %% [markdown]
# e) ¿Cuál será el mejor lugar para construir un barrio a lo largo de esta carretera?

# %% [markdown]
# f) Considerando los máximos, mínimos e intervalos de crecimiento, bosqueje la gráfica de la función.

# %% [markdown]
# ### Problema 7 📝

# %% [markdown]
# La función:
# $$f(x)=\frac{1}{500}x^5-\frac{23}{400}x^4+0,58x^3-2,36x^2+3,2x$$
# muestra el % de utilidades de una empresa los primeros 11 años de funcionamiento, donde $x$ corresponde a los años transcurridos desde su creación.
#
# A continuación, se presenta su gráfico:

# %% [markdown]
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# a) ¿Cuáles son las variables dependiente e independiente? Indique su unidad de medida.

# %% [markdown]
# b) Observando el gráfico, ¿para qué valores de $x$ se producen extremos relativos?

# %% [markdown]
# c) Considerando el código mostrado en la siguiente imagen, en el cual $f(x)$ corresponde a la función descrita en el problema, compruebe que los valores de $x$ identificados en el inciso b) satisfacen que $f'(x)=0$.

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# d) Calcule $f''(x)$.

# %% [markdown]
# e) Utilizando el criterio de la segunda derivada, determine si los valores críticos son mínimos o máximos locales. ¿Es coherente con lo observado en el gráfico?

# %% [markdown]
# ### Problema 8 📝

# %% [markdown]
# La complejidad temporal aproximada de un algoritmo según el tamaño de entrada $n$ se modela como:
#
# $$ T(n) = 3\ln(n) + \frac{20}{n} $$
#
# con $n > 0$ el número de elementos que contiene la entrada, en miles de elementos, y $T$ el tiempo medido en milisegundos.
#
# a) Calcule $T'(n)$.

# %% [markdown]
# b) Interprete la salida del código mostrado en la siguiente imagen:

# %% [markdown]
# <img src="https://i.imgur.com/RdFO1iO.jpeg" width="300">

# %% [markdown]
# c) Sabiendo que:
#
# $$T''(n)=-\frac{3}{n^2}+\frac{40}{n^3}$$
#
# Determine si el valor encontrado en el inciso b) genera un máximo o un mínimo local.

# %% [markdown]
# d) Determine los intervalos donde $T(n)$ aumenta y donde disminuye.

# %% [markdown]
# ### Problema 9 💻/🐍

# %% [markdown]
# En un servidor, el porcentaje de uso de CPU en función de la cantidad de procesos simultáneos $n$ se modela por:
#
# $$ U(n) = \frac{n^2+n+1}{n+1} $$
#
# donde $n$ es la cantidad de procesos. Este modelo es válido para un máximo de 20 procesos simultáneos.
#
# a) Determine los valores críticos de $U(n)$.

# %% [markdown]
# b) Utilizando el criterio de la segunda derivada, clasifique los valores críticos indicando si generan máximos o mínimos locales.

# %% [markdown]
# c) Determine los intervalos de crecimiento y decrecimiento.

# %% [markdown]
# d) ¿Con cuántos procesos se alcanza el máximo uso de CPU?

# %% [markdown]
# ### Problema 10 💻/🐍

# %% [markdown]
# La velocidad promedio de descarga por usuario, medida en Megabytes por segundo (Mbps), depende de la cantidad de usuarios conectados simultáneamente, y se puede aproximar mediante:
#
# $$ V(x) = 40-\frac{1}{5}x^5+2x^4-\frac{22}{3}x^3+12x^2-9x$$
#
# donde $x ≥ 0$. El máximo de usuarios que pueden conectarse simultáneamente es 5.
#
# a) Calcule los valores críticos de $V(x)$.

# %% [markdown]
# b) Utilizando el criterio de la segunda derivada, clasifique los valores críticos indicando si generan máximos o mínimos locales, o determine si generan puntos de inflexión.

# %% [markdown]
# c) Determine los intervalos donde la velocidad por usuario aumenta y donde disminuye.

# %% [markdown]
# d) ¿Para cuántos usuarios se obtiene la máxima velocidad por usuario?

# %% [markdown]
# ### Problema 11 💻/🐍

# %% [markdown]
# El número acumulado de intentos de ataque a un servidor por día se modela mediante:
#
# $$ A(t) = 100 - 80e^{-0.3t} $$
#
# donde $t$ es el tiempo en días desde que el servidor entró en producción.
#
# a) Calcule la derivada de $A(t)$.

# %% [markdown]
# b) Determine si $A(t)$ tiene valores críticos en $t ≥ 0$.

# %% [markdown]
# c) Analice el signo de la derivada para saber si $A(t)$ es creciente o decreciente.
