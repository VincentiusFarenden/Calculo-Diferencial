# %% [markdown]
# <img src="https://i.ibb.co/93sNcdhp/Logo-pmat-color.png" align="right" width="150">
#
# <br>
#
# # Funciones y sus gráficas

# %% [markdown]
# ## Objetivo:

# %% [markdown]
# En esta guía se trabajará con funciones elementales como lineales, polinómicas, exponenciales y con funciones de activación como ReLU y Sigmoide utilizando Python y cálculo analítico, para identificar su dominio, los intervalos de crecimiento y decrecimiento, y analizar cómo los parámetros de cada función influyen en su comportamiento y forma gráfica.

# %% [markdown]
# ## Instrucciones

# %% [markdown]
# Esta guía contiene problemas relacionados con funciones y sus gráficas, que debe resolver tanto de forma analítica como de forma computacional.
#
# Aquellos problemas marcados con 📝 son aquellos que debe resolver con lápiz y papel en su cuaderno, mientras que aquellos marcados con 💻/🐍 debe resolverlos usando Python.

# %% [markdown]
# # Problemas

# %%
# @title
# %%html
<div style="border: 4px solid #006d77; border-radius: 0px; overflow: hidden; font-family: sans-serif; max-width: 800px; margin-bottom: 20px;">

  <div style="background-color: #000000; color: #ffc107; padding: 10px 15px; font-weight: bold; font-size: 16px; display: flex; align-items: center;">
    <span style="margin-right: 10px; font-size: 18px;">💡</span>
    <span>Función lineal, cuadrática y polinomial</span>
  </div>

  <div style="background-color: #ffffff; padding: 20px; display: flex; align-items: center; justify-content: space-between;">

    <div style="color: #000000; flex: 1; padding-right: 30px; font-size: 14px; line-height: 1.5;">
      ¿Necesitas recordar las principales características de funciones lineales, cuadráticas o polinómicas?
      <b>Escanea o haz clic sobre el código QR</b> para visualizar cómo los coeficientes influyen en el comportamiento de una función.
    </div>

    <div style="flex-shrink: 0;">
      <a href="https://duoc.h5p.com/content/1292749263340562258" target="_blank">
        <img src="https://i.ibb.co/pvh2W2CN/gu-a-1-lineal-cuadra-poli.png"
             alt="QR Code"
             style="width: 100px; height: 100px; border: none;">
      </a>
    </div>

  </div>

  <div style="background-color: #000000; color: #ffc107; padding: 8px 15px; font-weight: bold; font-size: 16px;">
    Presentación interactiva H5P
  </div>

</div>
# Out:
# <div style="border: 4px solid #006d77; border-radius: 0px; overflow: hidden; font-family: sans-serif; max-width: 800px; margin-bottom: 20px;">
#
#   <div style="background-color: #000000; color: #ffc107; padding: 10px 15px; font-weight: bold; font-size: 16px; display: flex; align-items: center;">
#     <span style="margin-right: 10px; font-size: 18px;">💡</span>
#     <span>Función lineal, cuadrática y polinomial</span>
#   </div>
#
#   <div style="background-color: #ffffff; padding: 20px; display: flex; align-items: center; justify-content: space-between;">
#
#     <div style="color: #000000; flex: 1; padding-right: 30px; font-size: 14px; line-height: 1.5;">
#       ¿Necesitas recordar las principales características de funciones lineales, cuadráticas o polinómicas?
#       <b>Escanea o haz clic sobre el código QR</b> para visualizar cómo los coeficientes influyen en el comportamiento de una función.
#     </div>
#
#     <div style="flex-shrink: 0;">
# ...

# %% [markdown]
# ### Problema 1 📝

# %% [markdown]
# La función $f(x)$ muetra la rentabilidad de una empresa, expresada en porcentaje, durante los primeros 11 años de su creación.
#
# $$ f(x)=\frac{1}{500}x^5-\frac{23}{400}x^4+0,58x^3-2,36x^2+3,2x $$
#
# Donde $x$ es el tiempo transcurrido en años desde la creación de la empresa.
#
# *Nota: La rentabilidad indica qué tan eficiente es una empresa para obtener ganancias a partir de los recursos que invierte.*

# %% [markdown]
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# a) Identifique las variables dependiente e independiente indicando unidad de medida.

# %% [markdown]
# b) Escriba el dominio contextualizado de la función.

# %% [markdown]
# c) Considerando el dominio contextualizado, marque (destaque) en el gráfico, la porción de la curva que modela el problema.

# %% [markdown]
# d) Identifique los intervalos de crecimiento y decrecimiento de la rentabilidad de la empresa.

# %% [markdown]
# e) Considerando el dominio contextualizado de la función, ¿a los cuántos años de funcionamiento se observa la mayor y la menor rentabilidad? Indique los valores de rentabilidad correspondientes, redondeados a una décima.

# %% [markdown]
# ### Problema 2 📝

# %% [markdown]
# En una estación meteorológica, se está registrando la temperatura ambiente (en °C) durante la noche de un día invernal entre las 00:00 y las 06:00.
# La temperatura promedio se modela mediante la función:
#
# $$T(x)=x^2-6x+10$$
#
# donde $x$ representa la hora del día, medida desde la medianoche 00:00 hasta las 6:00 de la mañana.
#
# a) Identifique la variable dependiente e independiente.

# %% [markdown]
# b) ¿Cuál es el dominio contextualizado del problema?

# %% [markdown]
# c) ¿Cuál será la temperatura a las 1:00, 2:00, 3:00, 4:00, 5:00 y 6:00 de la mañana?

# %% [markdown]
# d) ¿La temperatura disminuye o aumenta al principio? ¿En qué basa su respuesta?

# %% [markdown]
# e) ¿Qué ocurre después de las 3:00 de la mañana?

# %% [markdown]
# f) Dentro de las temperaturas calculadas en la pregunta 2.c), ¿a qué hora la temperatura fue mínima? ¿Cúal fue la temperatura en esa hora?

# %% [markdown]
# g) Bosqueje la gráfica de la función.

# %% [markdown]
# h) A partir del gráfico, ¿cuándo se cumple que $T(x)=2$? Interprete estos valores.

# %% [markdown]
# ### Problema 3 💻/🐍

# %% [markdown]
# Una startup de inteligencia artificial lanza una plataforma web que usa modelos de lenguaje.
#
# Durante los 20 primeros días, el número de usuarios registrados se puede aproximar por la función:
#
# $$U(t)=500(1-e^{-0,1t})$$
#
# Donde $t$ corresponde al tiempo en días desde el lanzamiento.
#
# a) Identifique las variables dependiente e independiente.

# %% [markdown]
# b) Indique el dominio contextualizado de la función.

# %% [markdown]
# c) Genere e imprima una tabla que muestre la cantidad de usuarios registrados durante cada uno de los 10 primeros días desde el lanzamiento de la plataforma web.

# %%
import numpy as np

def U(t):                           #Definimos la función.
    return 500*(1-np.exp(-0.1*t))
print('t\t| U(t)')                  #Imprimimos los encabezados.
for x in range(11):                 #Creamos un iterador de 0 a 10.
    print(f'{x}\t| {U(x):.0f}')     #Imprimimos los valores de la variable independiente y de la función.
# Out:
# t	| U(t)
# 0	| 0
# 1	| 48
# 2	| 91
# 3	| 130
# 4	| 165
# 5	| 197
# 6	| 226
# 7	| 252
# 8	| 275
# 9	| 297
# 10	| 316

# %% [markdown]
# d) ¿Durante qué día se alcanzan los 400 usuarios?

# %%
import sympy as sp

t=sp.symbols('t')

U=sp.Lambda(t,500*(1-sp.exp(-0.1*t))) #Se define la función simbolica
ecuacion=sp.Eq(U(t),400) #Definimos la ecuacion

solucion=sp.solve(ecuacion,t) #Se busca la solucion de la ecuación, entregamos la ecuación y variable simbolica
print(solucion)
# Out:
# [16.0943791243410]

# %% [markdown]
# Los 400 usuarios se registran durante el día 16

# %% [markdown]
# e) Grafique la función $U(t)$ considerando el dominio contextualizado.

# %%
import numpy as np
import matplotlib.pyplot as plt


def U(t):
  return 500*(1-np.exp(-0.1*t))

x=np.linspace(0,20,100)

fig,ax=plt.subplots(figsize=(6,4))

ax.plot(x,U(x))

ax.set_title('Usuarios registrados en función del tiempo')

ax.set_xlabel('Tiempo (días)')
ax.set_ylabel('Usuarios registrados')

plt.show()

# %% [markdown]
# f) Analizando el gráfico, ¿la función continúa creciendo indefinidamente o tiende a estabilizarse? ¿Hacia qué valor parece acercarse?
#
# Vuelva a graficar ampliando el rango de $t$ si lo considera necesario.

# %%
import numpy as np
import matplotlib.pyplot as plt


def U(t):
  return 500*(1-np.exp(-0.1*t))

x=np.linspace(0,200,100)

fig,ax=plt.subplots(figsize=(6,4))

ax.plot(x,U(x))

ax.set_title('Usuarios registrados en función del tiempo')

ax.set_xlabel('Tiempo (días)')
ax.set_ylabel('Usuarios registrados')

plt.show()

# %% [markdown]
# ### Problema 4 💻/🐍

# %% [markdown]
# A continuación, se presenta un gráfico interactivo, a partir de la exploración de este responda las siguientes preguntas.
#
# De ser necesario, ejecute nuevamente el código para reiniciar el gráfico.

# %%
#@title Gráfico interactivo de función lineal
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact


def lineal(m=1, n=0):
    x = np.linspace(-10, 10, 200)
    y = m*x + n

    plt.figure(figsize=(6,6))
    plt.plot(x, y, label=f'f(x) = {m:.1f}x + {n:.1f}')

    # Ejes principales
    plt.axhline(0, color='gray', lw=1)
    plt.axvline(0, color='gray', lw=1)

    # Punto de intersección con eje y
    plt.scatter(0, n, color='red', s=60, zorder=5, label='Intersección con eje y')

    # Configuración de ejes y grilla
    plt.xlim(-10, 10)
    plt.ylim(-10, 10)
    plt.xticks(np.arange(-10, 11, 1))
    plt.yticks(np.arange(-10, 11, 1))
    plt.grid(True, which='both', linestyle='--', linewidth=0.7)

    plt.legend()
    plt.show()
    return None

# Deslizadores interactivos
_ = interact(lineal, m=(-5,5,0.1), n=(-5,5,0.1))
# Out:
# interactive(children=(FloatSlider(value=1.0, description='m', max=5.0, min=-5.0), FloatSlider(value=0.0, descr…

# %% [markdown]
# a) ¿Qué sucede con el gráfico al variar el valor de la pendiente $m$?

# %% [markdown]
# Al mover el valor de la pendiente solo se modifica la inclinación de la recta.

# %% [markdown]
# b) ¿Qué sucede con el gráfico al variar el coeficiente de posición $n$?

# %% [markdown]
# Al mover el coeficiente de posición, la recta se va desplazando en el eje Y

# %% [markdown]
# c) Para responder la siguiente pregunta, considere que en el gráfico, cada cuadro del plano representa una unidad en cada eje.
#
# Fije la pendiente $m=-3$ y el coeficiente de posición en $n=0$.
# 1) ¿Cuántas unidades cambia la recta en el eje $y$ por cada unidad que avanza en el eje $x$?¿En qué dirección ocurre ese cambio?
#
# Luego fije la pendiente en $m=1$.
#
# 2) ¿Cuántas unidades cambia la recta en el eje $y$ por cada unidad que avanza en el eje $x$?
# ¿En qué se diferencia con el caso anterior?

# %% [markdown]
# Por cada unidad, la pendiente indica que la función disminuye en 3 (es negativa)

# %% [markdown]
# d) Considerando que la pendiente m varía desde -5 hasta 5, mueva el deslizador y observe cómo cambia la inclinación de la recta. Describa qué ocurre con su dirección e inclinación cuando $m$ pasa de valores negativos a positivos.

# %% [markdown]
# ### Problema 5 📝

# %% [markdown]
# La altura promedio $H$ en centímetros, de un bebé durante su primer año de vida, se puede estimar mediante la función:
#
# $$H(a)=\frac{7}{3}a+48$$
#
# Donde $a$ corresponde a la edad del bebé en meses.
#
# a) Escriba el dominio contextualizado de la función.

# %% [markdown]
# El dominio contextualizado es de 0 a 12 meses

# %% [markdown]
# b) ¿Cuáles son las coordenadas inicial y final de la recta? ¿Cómo se interpretan esos valores?

# %%
import numpy as np

def H(a):
  return 7/3*a+48

print(f'Coordenada inicial es {H(0)} cms')
print(f'Coordenada final es {H(12)} cms')
# Out:
# Coordenada inicial es 48.0 cms
# Coordenada final es 76.0 cms

# %% [markdown]
# c) Determine e interprete la pendiente de la función.

# %% [markdown]
# Por cada mes, la altura aumenta en 7/3 cms

# %% [markdown]
# d) Esboce la gráfica de la función, considerando los puntos ya calculados.

# %%
import numpy as np
import matplotlib.pyplot as plt

def H(a):
  return 7/3*a+48

x=np.linspace(0,12,100)

fig,ax=plt.subplots(figsize=(8,4))

ax.plot(x,H(x))

ax.set_title('Altura de un bebé en función de su edad')

ax.set_xlabel('Edad (meses)')
ax.set_ylabel('Altura (cms)')

plt.show()

# %% [markdown]
# ### Problema 6 📝

# %% [markdown]
# Se analizaron las ventas de una empresa y se determinó que la función:
# $$V(t)=18+2t$$
#
# Modela adecuadamente los ingresos por ventas, en miles de dólares, donde $t$ corresponde al tiempo transcurrido en años desde el año 2000.
#
# Se estima que este modelo será válido hasta el año 2025.
#
# a) Escriba el dominio contextualizado de la función.

# %% [markdown]
# b) Esboce la gráfica de la función.

# %%
import numpy as np

import matplotlib.pyplot as plt

def V(t):
  return 18+2*t

x = np.linspace(2000,2025,100)

fig,ax = plt.subplots(figsize=(8,4))

ax.plot(x,V(x))

ax.set_title('Relacion entre tiempo(años) y ingresos por venta(miles de dolares)')

ax.set_xlabel('tiempo en (años)')

ax.set_ylabel('ingresos por venta(miles de dolares)')

plt.show()

# %% [markdown]
# c) Determine e interprete las coordenadas del punto inicial.

# %% [markdown]
# d) Determine e interprete la pendiente de la función.

# %% [markdown]
# e) ¿Cuáles son los valores mínimo y máximo de la función? Interprételos.

# %% [markdown]
# ### Problema 7 📝

# %% [markdown]
# Durante pruebas internas, un equipo de desarrollo registra el tiempo que tarda un modelo de machine learning (ML) en completar una época de entrenamiento. El tiempo $T$, medido en segundos, es función del tamaño del dataset $x$, medido en miles de ejemplos.
#
# En el rango de valores analizados, se estima que el comportamiento es aproximadamente el de una función lineal:
#
# $$T(x)=mx+n$$
#
# Se sabe que para un dataset de 20.000 ejemplos, el tiempo por época es de 62 segundos. Por otro lado, para un dataset de 50.000 ejemplos el tiempo por época es de 152 segundos.
#
# a) Identifique la variable dependiente e independiente, indicando su unidad de medida.

# %%
import sympy as sp

m, n = sp.symbols('m n') #Identificamos las variables simbólicas

#Ecuaciones con los dos puntos conocidos del enunciado

eq1 = sp.Eq(62, m*20 + n) #Para x=20 mil ejemplos, T=62 segundos

display(eq1)

eq2 = sp.Eq(152, m*50 + n) #Para x=50 mil ejemplos, T=152 segundos

display(eq2)
# Out:
# Eq(62, 20*m + n)
# Eq(152, 50*m + n)

# %%
solucion = sp.solve((eq1, eq2), (m, n)) #Se resuelven las ecuaciones

print(f"Pendiente m = {solucion[m]} mil ejemplos")
print(f"Intercepto n = {solucion[n]} segundos")
# Out:
# Pendiente m = 3 mil ejemplos
# Intercepto n = 2 segundos

# %% [markdown]
# Variable independiente es la cantidad de dataset
#
# La variable dependiente es el tiempo por época en segundos

# %% [markdown]
# b) Calcule e interprete la pendiente de la función.

# %%
import numpy as np

# Definimos las incógnitas

m, n = sp.symbols('m n')

# Ecuaciones con los dos puntos conocidos del enunciado

eq1 = sp.Eq(62, m*20 + n)   # Para x=20 mil ejemplos, T=62 segundos

display(eq1)

eq2 = sp.Eq(152, m*50 + n)  # Para x=50 mil ejemplos, T=152 segundos

display(eq2)

# Resolver

solucion = sp.solve((eq1, eq2), (m, n))

print(f"Pendiente m = {solucion[m]} mil ejemplos")

print(f"Intercepto n = {solucion[n]} segundos")
# Out:
# Eq(62, 20*m + n)
# Eq(152, 50*m + n)
# Pendiente m = 3 mil ejemplos
# Intercepto n = 2 segundos

# %% [markdown]
# Por cada 1000 ejemplos, el tiempo de procesado va a aumentar en 3 segundos.

# %% [markdown]
# c) Determine la forma algebraica de la función que modela el problema.

# %%
print('T(x)=3*x+2')
# Out:
# T(x)=3*x+2

# %% [markdown]
# d) ¿Cuál es el tiempo por época para un dataset de 80.000 ejemplos?

# %%
def T(x):
  return 3*x+2

print(f'El tiempo por época para un dataset de 80 mil ejemplos es de {T(80)} segundos')
# Out:
# El tiempo por época para un dataset de 80 mil ejemplos es de 242 segundos

# %% [markdown]
# e) ¿Para qué tamaño de dataset el tiempo de época sería de 200 segundos?

# %%
solucion = sp.solve(3*m+2-200,m)

print(f'El tamaño del dataset para el tiempo de época de 200 segundos es de {solucion[0]} mil ejemplos')
# Out:
# El tamaño del dataset para el tiempo de época de 200 segundos es de 66 mil ejemplos

# %% [markdown]
# ### Problema 8 💻/🐍

# %% [markdown]
# Un equipo de TI está monitoreando el tráfico de datos en la red de la empresa. Han registrado el volumen de los datos transferidos y el tiempo que tomó cada transferencia en la siguiente tabla de datos:
#
# <p><center>
#
# |Datos transferidos (GB) | Tiempo de transferencia (min)|
# |------------------------|------------------------------|
# |$$5$$                   |$$10$$                        |
# |$$10$$                  |$$20$$                        |
# |$$25$$                  |$$50$$                        |
# |$$50$$                  |$$100$$                       |
# |$$100$$                 |$$200$$                       |
#
# </center></p>
#
# a) Defina variable dependiente e independiente, indicando unidad de medida.

# %% [markdown]
# Variable independiente son los datos transferidos en GB y la variable dependiente es el tiempo de transferencias en minutos.

# %% [markdown]
# b) Utilizando la función *polyfit* de *Numpy* encuentre la función lineal que modela el tiempo de transferencia $T(x)$ en función del volumen de los datos transferidos.

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

datos=[5,10,25,50,100]
tiempo=[10,20,50,100,200]

m,n=np.polyfit(datos,tiempo,1)

print(f'La pendiente es {m:.2f} y el intercepto es {n:.2f}')

print(f'T(x)=2*x')
# Out:
# La pendiente es 2.00 y el intercepto es 0.00
# T(x)=2*x

# %% [markdown]
# c) Interprete la pendiente en el contexto del problema.

# %% [markdown]
# Por cada GB entregado a transferir, el tiempo de transferencia aumentará 2 minutos.

# %% [markdown]
# d) ¿Cuánto tiempo toma una transferencia de 73,2 GB?

# %%
def T(x):
  return 2*x

print(f'El tiempo de transferencia para 73,2 Gb es de {T(73.2)} minutos.')
# Out:
# El tiempo de transferencia para 73,2 Gb es de 146.4 minutos.

# %% [markdown]
# e) Utilizando Python, determina la cantidad de datos que se puedan transferir en 123,5 minutos.

# %% [markdown]
# f) Grafique la función $T(x)$ indicando el nombre de los ejes y su unidad de medida. Interprete lo observado. Para graficar utiliza la biblioteca *matplotlib*.

# %%
# @title
# %%html
<div style="border: 4px solid #006d77; border-radius: 0px; overflow: hidden; font-family: sans-serif; max-width: 800px; margin-bottom: 20px;">

  <div style="background-color: #000000; color: #ffc107; padding: 10px 15px; font-weight: bold; font-size: 16px; display: flex; align-items: center;">
    <span style="margin-right: 10px; font-size: 18px;">💡</span>
    <span>Función por partes y ReLU</span>
  </div>

  <div style="background-color: #ffffff; padding: 20px; display: flex; align-items: center; justify-content: space-between;">

    <div style="color: #000000; flex: 1; padding-right: 30px; font-size: 14px; line-height: 1.5;">
       <b>Escanea o haz clic sobre el código QR</b> para revisar el comportamiento dinámico de
       la función ReLU y entiende visualmente los conceptos de "neurona encendida/apagada” antes de calcular.
    </div>

    <div style="flex-shrink: 0;">
      <a href="https://duoc.h5p.com/content/1292758026045111788" target="_blank">
        <img src="https://i.ibb.co/fdRhb4pd/gu-a-1-Re-LU.png"
             alt="QR Code"
             style="width: 100px; height: 100px; border: none;">
      </a>
    </div>

  </div>

  <div style="background-color: #000000; color: #ffc107; padding: 8px 15px; font-weight: bold; font-size: 16px;">
    Presentación interactiva H5P
  </div>

</div>
# Out:
# <div style="border: 4px solid #006d77; border-radius: 0px; overflow: hidden; font-family: sans-serif; max-width: 800px; margin-bottom: 20px;">
#
#   <div style="background-color: #000000; color: #ffc107; padding: 10px 15px; font-weight: bold; font-size: 16px; display: flex; align-items: center;">
#     <span style="margin-right: 10px; font-size: 18px;">💡</span>
#     <span>Función por partes y ReLU</span>
#   </div>
#
#   <div style="background-color: #ffffff; padding: 20px; display: flex; align-items: center; justify-content: space-between;">
#
#     <div style="color: #000000; flex: 1; padding-right: 30px; font-size: 14px; line-height: 1.5;">
#        <b>Escanea o haz clic sobre el código QR</b> para revisar el comportamiento dinámico de
#        la función ReLU y entiende visualmente los conceptos de "neurona encendida/apagada” antes de calcular.
#     </div>
#
#     <div style="flex-shrink: 0;">
#       <a href="https://duoc.h5p.com/content/1292758026045111788" target="_blank">
# ...

# %% [markdown]
# ### Problema 9 📝

# %% [markdown]
# En este problema analizaremos la función $ReLU(x)$ definida como:
#
# $$ReLU(x)=max(0,x)$$
#
# Para $x\in\{-4,-2, 0, 1, 3, 5\}$.
#
# a) Evalúe $ReLU(x)$ en todos los valores dados de $x$. ¿Qué puede notar? ¿Hay alguna cambio en el comportamiento?

# %% [markdown]
# El punto de inflexión en el comportamiento de la función ReLu(x) es cuando x es igual a 0. Para los valores negativos la función es 0, y para los valores positivos entrega el mismo valor de x.

# %% [markdown]
# b) Bosqueje la gráfica de la función $ReLU(x)$.

# %%
import numpy as np
import matplotlib.pyplot as plt

def ReLu(x):
  return np.maximum(0,x)

x=np.linspace(-30,30,100)
fig,ax=plt.subplots(figsize=(8,4))

ax.plot(x,ReLu(x))
plt.grid(True)

# %% [markdown]
# c) Describa la gráfica de esta función, considerando qué sucede para los valores negativos y para los valores positivos.

# %% [markdown]
# Para valores negativos la función es igual a 0, para valores positivos la función es igual a la "identidad"

# %% [markdown]
# d) ¿Para qué valores de $x$ diría que esta función está "Activada" y para cuáles "Apagada"?

# %% [markdown]
# Para los valores menores a x estaría apagada, y para los valores mayores o iguales a "x" está activada.

# %% [markdown]
# ### Problema 10  📝

# %% [markdown]
# a) Grafique simultáneamente las funciones $ReLU(x)$ y $f(x)=x$ en un mismo gráfico en el intervalo $-10\leq x\leq 10$.

# %%
import numpy as np
import matplotlib.pyplot as plt

def ReLu(x):
  return np.maximum(0,x)

def f(x):
  return x

x=np.linspace(-10,10,100)
fig,ax=plt.subplots(figsize=(8,4))

ax.plot(x,ReLu(x), label="f(x)")
ax.plot(x,f(x), label="ReLu")
plt.grid(True)
plt.legend()

# %% [markdown]
# b) ¿Para qué valores de $x$ estas funciones coinciden?

# %% [markdown]
# Las funciones coinciden para todos los valores mayores a 0.

# %% [markdown]
# ### Problema 11 💻/🐍

# %% [markdown]
# A continuación, se presenta un gráfico interactivo de la función $ReLU(x)$ paramétrica dada por:
#
# $$f(x)=a\cdot ReLU(x-b)+c$$
#
# A partir del análisis de esta gráfica, responda las siguientes preguntas.

# %%
#@title ReLU paramétrica
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as W
from IPython.display import clear_output, display

x = np.linspace(-6, 6, 400)

# Deslizadores
a = W.FloatSlider(value=1.0, min=-3, max=3, step=0.1, description='a')
b = W.FloatSlider(value=0.0, min=-3, max=3, step=0.1, description='b')
c = W.FloatSlider(value=0.0, min=-3, max=3, step=0.1, description='c')

out = W.Output()

def dibujo(*_):
    with out:
        clear_output(wait=True)
        y = a.value * np.maximum(0, x - b.value) + c.value
        fig, ax = plt.subplots(figsize=(7,4))
        ax.plot(x, y, lw=2, label='f(x)')
        ax.axvline(b.value, color='purple', ls=':', lw=1.5, label='umbral b')
        ax.scatter([b.value],[c.value], s=70, color='red', zorder=5, label='bisagra (b,c)')
        y0 = a.value*np.maximum(0, -b.value) + c.value
        ax.scatter([0],[y0], s=60, color='black', zorder=5, label='intersección y')
        ax.axhline(0, color='gray', lw=1); ax.axvline(0, color='gray', lw=1)
        ax.set_xlim(-6,6); ax.set_ylim(-6,10)
        ax.set_xticks(np.arange(-6,7,1)); ax.set_yticks(np.arange(-6,11,1))
        ax.grid(True, ls='--', lw=0.7)
        ax.set_title(f'f(x) = {a.value:.1f}·ReLU(x - {b.value:.1f}) + {c.value:.1f} | f(0)={y0:.2f}')
        ax.legend(loc='upper left', ncols=2)
        plt.show()

# dibuja y conecta eventos
dibujo()
for w in (a,b,c):
    w.observe(dibujo, names='value')

display(W.VBox([W.HBox([a,b,c]), out]))

# %% [markdown]
# a) ¿Qué sucede con la función a medida que cambia el valor de $a$? ¿Este cambio afecta a la parte activada o desactivada?

# %% [markdown]
# Cuando el valor de a cambia, la pendiente de la función modifica donde empieza su inclinación.

# %% [markdown]
# b) ¿Qué sucede en el gráfico cuando cambia el valor de $b$? Este parámetro se conoce como bisagra,  ¿por qué crees que recibe este nombre?

# %% [markdown]
# Cuando b cambia, la función f(x) cambia su punto de inflexión.

# %% [markdown]
# c)¿Qué observa en el gráfico a medida que cambia el valor de $c$? ¿Este cambio afecta a la parte activada, desactivada o a ambas?

# %% [markdown]
# Cuando c cambia, la función se desplaza en el eje Y

# %% [markdown]
# d) Si definimos $f(x)=3ReLU(x-2)+1$, ¿Cuánto vale $f(1)$ y $f(5)$?

# %%
import numpy as np

def relu(x):
  return np.maximum(0,x)

def f(x):
  return 3*relu(x-2)+1

print(f'f(1)={f(1)}')
print(f'f(5)={f(5)}')
# Out:
# f(1)=1
# f(5)=10

# %% [markdown]
# ### Problema 12 💻/🐍

# %% [markdown]
# A continuación, se presenta un gráfico dinámico de una función cuadrática, donde puedes variar los parámetros $a$, $b$ y $c$ para estudiar la forma de la función.
#
# A partir de esto, explora el gráfico y responde las siguientes preguntas.

# %%
#@title Parábola cuadrática con deslizadores (a, b, c)
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as W
from IPython.display import clear_output, display

# Eje x para graficar
x = np.linspace(-8, 8, 600)

# Sliders
a = W.FloatSlider(value=1.0, min=-3.0, max=3.0, step=0.1, description='a')
b = W.FloatSlider(value=0.0, min=-6.0, max=6.0, step=0.1, description='b')
c = W.FloatSlider(value=0.0, min=-6.0, max=6.0, step=0.1, description='c')
out = W.Output()

def draw(*_):
    with out:
        clear_output(wait=True)
        # función
        y = a.value*x**2 + b.value*x + c.value

        fig, ax = plt.subplots(figsize=(7, 4))
        ax.plot(x, y, lw=2, label='f(x) = a·x² + b·x + c')

        # Ejes y grilla
        ax.axhline(0, color='gray', lw=1)
        ax.axvline(0, color='gray', lw=1)
        ax.set_xlim(-8, 8); ax.set_ylim(-10, 10)
        ax.set_xticks(np.arange(-8, 9, 1))
        ax.set_yticks(np.arange(-10, 11, 1))
        ax.grid(True, which='both', linestyle='--', linewidth=0.7)

        # Corte con eje y (x=0): y = c
        ax.scatter([0], [c.value], s=60, color='black', label='intersección eje y')

        # Vértice y eje de simetría (si a != 0)
        eps = 1e-12
        if abs(a.value) > eps:
            xv = -b.value/(2*a.value)
            yv = a.value*xv**2 + b.value*xv + c.value
            ax.scatter([xv], [yv], s=70, color='red', zorder=5, label='vértice')
            ax.axvline(xv, color='purple', ls=':', lw=1.5, label='eje simetría')

            # Raíces reales si el discriminante es >= 0
            D = b.value**2 - 4*a.value*c.value
            if D >= 0:
                r1 = (-b.value - np.sqrt(D)) / (2*a.value)
                r2 = (-b.value + np.sqrt(D)) / (2*a.value)
                ax.scatter([r1, r2], [0, 0], s=70, color='green', label='raíces reales')
                roots_txt = f"raíces: {r1:.2f}, {r2:.2f}"
            else:
                roots_txt = "sin raíces reales"
            title_extra = f"  |  vértice=({xv:.2f}, {yv:.2f}), {roots_txt}"
        else:
            # Caso casi lineal: f(x) ≈ b x + c
            title_extra = "  |  (a≈0 ⇒ función casi lineal)"

        ax.set_title(f"f(x) = {a.value:.1f}·x² + {b.value:.1f}·x + {c.value:.1f}{title_extra}")
        ax.legend(loc='upper left', ncols=2)
        plt.show()

# dibuja y conecta
draw()
for w in (a, b, c):
    w.observe(draw, names='value')

display(W.VBox([W.HBox([a, b, c]), out]))

# %% [markdown]
# a) ¿Qué sucede con la parábola al cambiar el signo de $a$?

# %% [markdown]
# Cuando a es positivo, la parábola es cóncava hacia arriba, cuando a es 0 es una recta, y cuando a es negativo la parábola es una cóncava hacia abajo.

# %% [markdown]
# b) ¿Para qué valores de $a$ el vértice de la función es un valor máximo? ¿Para qué valores de $a$ es un mínimo?

# %% [markdown]
# Cuando a es positivo se habla de un mínimo del vértice, cuando a es negativo se habla de la altura o el valor máximo que alcanza el vértice.

# %% [markdown]
# c) Si variamos $a$ sin que cambie de signo, ¿cómo se modifica la forma de la parábola? ¿Cómo cambia?

# %% [markdown]
# La parábola es más cerrada o más abierta según el valor de a.

# %% [markdown]
# d) ¿Qué sucede con la gráfica de la función al variar el valor de $c$? ¿La gráfica cambia de forma?

# %% [markdown]
# La parábola no cambia su forma ni su orientación, pero cambia la altura del intercepto del eje Y

# %% [markdown]
# Para las preguntas e), f), g) y h) fije llos parámetros de la función en $a=1$, $b=2$ y $c=-3$.
# Luego, responda observando el gráfico.

# %% [markdown]
# e) ¿Cuál es la forma algebraica de la función representada?

# %% [markdown]
# $f(x) = x^2 + 2x - 3$

# %% [markdown]
# f) ¿Cuáles son las coordenadas del vértice de la parábola? ¿Coinciden estos puntos con lo que muestra la gráfica?

# %%
def f1(x):
  return x**2+2*x-3

coord1 = -2/2

print(f'El vértice de la parábola es ({coord1}, {f1(coord1)})')
# Out:
# El vértice de la parábola es (-1.0, -4.0)

# %% [markdown]
# g) ¿Cuáles son las coordenadas de las intersecciones con el eje $x$? ¿Coinciden estos puntos con lo que muestra la gráfica?

# %%
import sympy as sp

x = sp.symbols('x')
f = sp.Lambda(x, x**2+2*x-3)
ecuacion = sp.Eq(f.expr,0)
solucion = sp.solve(ecuacion,x)
display(solucion)
# Out:
# [-3, 1]

# %% [markdown]
# h) ¿Existe algún valor de $x$ para el cual $f(x)=-5$? Justifica tu respuesta

# %% [markdown]
# No, ya que el punto mínimo de f(x) es -4 en el vértice, por lo tanto no existe valor de x para -5

# %% [markdown]
# i) Determine las coordenadas de la intersección con el eje $y$. ¿Coinciden estos puntos con lo que muestra la gráfica?

# %% [markdown]
# El punto de intersección con el eje "y" está en el punto (0,-3). Este punto coincide con la gráfica.

# %% [markdown]
# ### Problema 13 📝

# %% [markdown]
# Cada 7 años se renueva la directiva del club campestre "Cartagua's Club". Durante la segunda administración, las utilidades por el arriendo de las cabañas, medidas en euros, se ajustan a la función: $$R(x)=x^2-100x+2.100$$
#
# Donde $x$ corresponde a los meses transcurridos desde la segunda directiva.

# %% [markdown]
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# a) Escriba el dominio contextualizado de la función.

# %% [markdown]
# El dominio contextualizado es de 0 a 84 meses.

# %% [markdown]
# b) En la gráfica, marque la porción de la parábola que modela el problema y escriba las coordenadas inicial y final.

# %%
import numpy as np
import matplotlib.pyplot as plt

def R(x):
  return x**2-100*x+2100

x=np.linspace(0,84,100) #Escribimos el dominio contextualizado
fig,ax=plt.subplots(figsize=(6,4))
ax.plot(x,R(x),label="R(x)")
plt.grid(True)
plt.show()

print(f'A los 0 meses la utilidad es de {R(0)} Euros')
print(f'A los 84 meses la utilidad es de {R(84)} Euros')
# Out:
# A los 0 meses la utilidad es de 2100 Euros
# A los 84 meses la utilidad es de 756 Euros

# %% [markdown]
# c) Sabiendo que el vértice de la función tiene coordenadas $(50,-400)$, interprételo en el contexto del problema.

# %% [markdown]
# En el mes 50, las utilidades fueron de -400 euros

# %% [markdown]
# d) Se ejecuta el siguiente código, ¿cómo interpreta los resultados que imprime? Considere el contexto del problema.

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# 30 y 70 son los meses en los cuales la utilidad es 0, y 2100 indica la inversión inicial en Euros de la empresa.

# %% [markdown]
# e) Determine e interprete los intervalos de crecimiento y decrecimiento de la función.

# %% [markdown]
# De 0 a 50 meses, la función es decreciente, mientras que en el mes 51 al 84 es creciente. Por lo que en ese último intervalo, las utilidades fueron positivas para la empresa.

# %% [markdown]
# ### Problema 14 💻/🐍

# %% [markdown]
# La temperatura de un día, en grados Celsius, se puede modelar con la función $C(t)=\frac{-1}{6}t^2+4t-\frac{22}{3}$, donde $t$ representa las horas transcurridas del día.

# %% [markdown]
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# a) Escriba el dominio contextualizado de la función.

# %% [markdown]
# b) Usando *sympy*, encuentra las raíces de la función e interpretelas.

# %% [markdown]
# c) Calcule las coordenadas del vértice de la parábola e interpretelo.

# %% [markdown]
# d) Construya la gráfica de la función, considerando sólo el dominio contextualizado, agregando el título y nombre de los ejes, con unidad de medida.
#
# *Pista: Recuerde que los ejes puede agregarlos con axhline(0) y axvline(0) y que los puntos puede agregarlos con scatter(x,y). Todos estos son métodos que se aplican sobre el eje.*

# %% [markdown]
# ###Problema 15 💻/🐍

# %% [markdown]
# En una base de datos, un índice es una estructura asociada a una o varias columnas de una tabla.
#
# Cuando hay pocos índices, las búsquedas en la tabla se ralentizan, ya que se debe recorrer toda la tabla para encontrar los datos.
#
# Por el contrario, cuando hay muchos índices, las escrituras y actualizaciones se vuelven más lentas, porque se debe actualizar cada índice cada vez que cambia la información.
#
#
#
# Se presume que la relación entre el costo promedio por operación $C(k)$, medido en milisegundos, y la cantidad de índices en una base de datos es cuadrática.
#
#
# El costo para algunos índices es el siguiente:
#
# | k (nº de índices) | 0 | 2 | 4 | 6 | 8 | 10 |
# | --- | ---: | ---: | ---: | ---: | ---: | ---: |
# | Costo (ms) | 34,6  | 24,4 | 20,5 | 23,1 | 32,1 | 47,4 |
#
# a) Indentifique la variable dependiente e independiente indicando su unidad de medida.

# %% [markdown]
# b) Usando *polyfit* de *numpy* determine la forma algebraica de la función que modela el problema, aproxime los parámetros de la función con dos decimales.

# %% [markdown]
# c) ¿Cuál será el costo promedio por operación, si la estructura tiene 5 índices?

# %% [markdown]
# d) ¿Cuántos índices tiene una estructura, si el costo promedio de operación es de 26,8 ms?

# %% [markdown]
# e) Grafique la función y la lista de valores dada para verificar que corresponden.

# %% [markdown]
# ### Problema 16 💻/🐍

# %% [markdown]
# Una estimación de la temperatura diaria promedio (en grados Celsius) de un pueblo de América del Norte, durante el año 2000, desde inicios de febrero hasta mediados de diciembre se obtiene mediante la función:
#
# $$f(x)=\frac{1}{60}x^6-\frac{3}{5}x^5+8,15x^4-51,6x^3+151,65x^2-178,1x+65$$
#
# donde $x$ corresponde al tiempo transcurrido en meses desde el inicio de ese año.
#
# a) Escriba el dominio contextualizado de la función. Considere para esto cuántos meses han pasado desde el comienzo hasta la mitad del mes de diciembre.

# %% [markdown]
# b) Grafique la función en el dominio contextualizado.

# %% [markdown]
# c) Identifique en el gráfico para que valores de $x$ ocurren las temperaturas máximas y mínimas. ¿A qué meses corresponden?

# %% [markdown]
# d) Calcule la temperatura máxima y mínima global dentro del dominio contextualizado.

# %% [markdown]
# e) Identifique los intervalos de crecimiento y decrecimiento de las temperaturas dentro del dominio contextualizado.

# %% [markdown]
# f) ¿Para qué valores de $x$ la temperatura vale 0? ¿A qué meses corresponde?

# %% [markdown]
# ### Problema 17 💻/🐍

# %% [markdown]
# Se tiene el siguiente conjunto de datos $(x, y)$. Se sospecha que los datos siguen (aproximadamente) un polinomio de grado 5:
#
# | x   | -3,0 | -2,5   | -2,0 | -1,5  | -1,0 | -0,5  | 0,0 | 0,5 | 1,0 | 1,5  | 2,0 | 2,5   | 3,0 |
# |----:|-----:|-------:|-----:|------:|-----:|------:|----:|----:|----:|-----:|----:|------:|----:|
# | y   | -210 | -55,6875 | 0 | 7,875 | 0 | -6,5625 | -6 | 0 | 6 | 6,5625 | 0 | -7,875 | 0 |
#
# a) Encuentra la forma algebraica de la función que modela el problema.

# %% [markdown]
# b) Realice la gráfica de la función para $-3\leq x\leq 3$.

# %%
# @title
# %%html
<div style="border: 4px solid #006d77; border-radius: 0px; overflow: hidden; font-family: sans-serif; max-width: 800px; margin-bottom: 20px;">

  <div style="background-color: #000000; color: #ffc107; padding: 10px 15px; font-weight: bold; font-size: 16px; display: flex; align-items: center;">
    <span style="margin-right: 10px; font-size: 18px;">💡</span>
    <span>Función exponencial y sigmoide/logística</span>
  </div>

  <div style="background-color: #ffffff; padding: 20px; display: flex; align-items: center; justify-content: space-between;">

    <div style="color: #000000; flex: 1; padding-right: 30px; font-size: 14px; line-height: 1.5;">
       <b>Escanea o haz clic sobre el código QR</b> para diferenciar entre un crecimiento explosivo
       (exponencial) y uno que se satura o estabiliza (sigmoide/logística).
    </div>

    <div style="flex-shrink: 0;">
      <a href="https://duoc.h5p.com/content/1292758025892494508" target="_blank">
        <img src="https://i.ibb.co/rRFWkWTm/gu-a-1-expo-y-sigm.png"
             alt="QR Code"
             style="width: 100px; height: 100px; border: none;">
      </a>
    </div>

  </div>

  <div style="background-color: #000000; color: #ffc107; padding: 8px 15px; font-weight: bold; font-size: 16px;">
    Presentación interactiva H5P
  </div>

</div>
# Out:
# <div style="border: 4px solid #006d77; border-radius: 0px; overflow: hidden; font-family: sans-serif; max-width: 800px; margin-bottom: 20px;">
#
#   <div style="background-color: #000000; color: #ffc107; padding: 10px 15px; font-weight: bold; font-size: 16px; display: flex; align-items: center;">
#     <span style="margin-right: 10px; font-size: 18px;">💡</span>
#     <span>Función exponencial y sigmoide/logística</span>
#   </div>
#
#   <div style="background-color: #ffffff; padding: 20px; display: flex; align-items: center; justify-content: space-between;">
#
#     <div style="color: #000000; flex: 1; padding-right: 30px; font-size: 14px; line-height: 1.5;">
#        <b>Escanea o haz clic sobre el código QR</b> para diferenciar entre un crecimiento explosivo
#        (exponencial) y uno que se satura o estabiliza (sigmoide/logística).
#     </div>
#
#     <div style="flex-shrink: 0;">
#       <a href="https://duoc.h5p.com/content/1292758025892494508" target="_blank">
# ...

# %% [markdown]
# ### Problema 18 💻/🐍

# %% [markdown]
# Se realiza una inversión de $500.000 en un depósito a plazo que tiene una tasa de interés compuesto del 0,9% mensual.
#
# a) Determine la forma algebraica de la función $f(x)$, donde $x$ corresponde al tiempo en meses.

# %% [markdown]
# b) Calcule el dinero que tendrá luego de 3, 4 y 5 meses si mantiene el dinero en el depósito a plazo.

# %% [markdown]
# c) Grafique la función durante los primeros 10 años que el dinero se encuentra dentro del depósito a plazo.
#
# *Nota: Para evitar la notación científica en los gráficos, puede usar la siguiente línea de código:*
#
#
#
# ```
# ax.ticklabel_format(style='plain', useOffset=False, axis='both')
# ```

# %% [markdown]
# ### Problema 19 💻/🐍

# %% [markdown]
# Un paracaidista salta desde una altura razonable sobre el suelo. La velocidad de descenso del paracaidista en el tiempo $t$ se expresa como $v(t)=24(1-e^{-0,2x})$ donde $t$ se mide en segundos y $v(t)$ se mide en metros por segundo $(m/s)$.
#
# Se estima que la caída dura alrededor de 2 minutos.
#
# a) Determine la velocidad inicial del paracaidista.

# %% [markdown]
# b) Calcule la velocidad luego de 5 y de 10 segundos.

# %% [markdown]
# c) Grafique la función durante el tiempo de caída.

# %% [markdown]
# d) ¿Qué sucede con la velocidad a medida que cae al comienzo del movimiento? ¿Para tiempos largos, aumenta indefinidamente o se estabiliza?

# %% [markdown]
# ### Problema 20 💻/🐍

# %% [markdown]
# En este problema, exploraremos la función sigmoide $\sigma(x)$.
#
# Recuerde que:
#
# $$\sigma(x)=\frac{1}{1+e^{-x}}$$
#
# a) Defina en Python la función sigmoide y luego calcule:
# - $f(-5)$
# - $f(-1)$
# - $f(0)$
# - $f(1)$
# - $f(5)$
#
# Use para esto tres decimales.
#
# ¿Qué puedes observar de estos valores?

# %% [markdown]
# b) Grafique la función $\sigma(x)$ para $-10\leq x\leq 10$.

# %% [markdown]
# c) ¿Hacia qué valores parece estabilizarse la función para valores de $x$ muy negativos y muy positivos? ¿Es coherente lo observado en el gráfico con lo analizado en el primer inciso?

# %% [markdown]
# d) En redes neuronales, las funciones de activación como la sigmoide permiten representar si una neurona está encendida o apagada según su nivel de activación.
#
# Como $\sigma(x)$ no es binaria (no vale solo 0 o 1), se define un umbral para decidir cuándo una neurona se activa. Si se define que una neurona está encendida cuando $\sigma(x)\geq 0,3$. ¿Para qué valores de $x$ consideraremos que una neurona está encendida?

# %% [markdown]
# ### Problema 21 💻/🐍

# %% [markdown]
# Se define la siguiente función por partes como:
#
# $$
# f(x)=
# \begin{cases}
# -4,      & \text{si } x \le 1, \\
# 2x-6,    & \text{si } x > 1 .
# \end{cases}
# $$
#
# a) Defina esta función usando Python y luego evalúela en los valores $x=\{-2,-1,0,1,2\}$.

# %% [markdown]
# b) Construya la gráfica de la función para $-5\leq x\leq 5$.
#
# *Considere graficar en dos partes, desde el inicio hasta $-1$ y luego de $-1$ hasta el final, de otro modo, la gráfica de la función rellenará los saltos que tiene la función.*

# %% [markdown]
# ### Problema 22 💻/🐍

# %% [markdown]
# Para el cálculo de la calificación de una evaluación de 40 puntos, se usa una función definida por partes, donde cada tramo corresponde a una función lineal.
#
# Desde 0 a 24 puntos, se utiliza una función que pasa por:
#
# |Puntaje|Nota|
# |:--:|:--:|
# |4|1,5|
# |12|2,5|
# |16|3|
#
# Mientras que para los puntajes superiores a 24, se utiliza la función que pasa por los puntos:
#
# |Puntaje|Nota|
# |:--:|:--:|
# |32|5,5|
# |40|7|
#
# a) Usando Polyfit determine las expresiones algebraicas de las funciones que describen cada parte del problema.

# %% [markdown]
# b) Usando *sympy*, construya la función por partes que modela el problema.

# %% [markdown]
# c) Usando esta función, determine qué calificaciones tendrían estudiantes con 0, 10, 20, 30 y 40 puntos.

# %% [markdown]
# d) Grafique la función obtenida.
